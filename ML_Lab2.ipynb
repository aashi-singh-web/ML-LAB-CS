# %% [markdown]
# <a href="https://colab.research.google.com/github/aashi-singh-web/ML-LAB-CS/blob/main/ML_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
df = pd.read_csv("BostonHousing.csv")
print("Missing values (True/False):")
print(df.isnull())

print("\nTotal missing values in each column:")
print(df.isnull().sum())
# Out:
#      <input type="file" id="files-4e20dfbc-b8b7-4cbb-bf1c-75a26907ba4a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e20dfbc-b8b7-4cbb-bf1c-75a26907ba4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
before = df.shape
df_cleaned = df.dropna()
after = df_cleaned.shape

print("Dataset size before cleaning:", before)
print("Dataset size after cleaning:", after)
# Out:
# Dataset size before cleaning: (506, 14)
# Dataset size after cleaning: (506, 14)

# %%
df['rm'] = df['rm'].fillna(df['rm'].mean())
df['lstat'] = df['lstat'].fillna(df['lstat'].median())
print(df.isnull().sum())
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
print("Before conversion:")
print(df.dtypes)

df['chas'] = df['chas'].astype(int)
df['rad'] = df['rad'].astype(int)

print("\nAfter conversion:")
print(df.dtypes)
# Out:
# Before conversion:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object
#
# After conversion:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
df = df.rename(columns={
    'crim': 'Crime Rate',
    'rm': 'Avg Rooms',
    'medv': 'House Price'
})

print(df.head())
# Out:
#    Crime Rate    zn  indus  chas    nox  Avg Rooms   age     dis  rad  tax  \
# 0     0.00632  18.0   2.31     0  0.538      6.575  65.2  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469      6.421  78.9  4.9671    2  242
# 2     0.02729   0.0   7.07     0  0.469      7.185  61.1  4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458      6.998  45.8  6.0622    3  222
# 4     0.06905   0.0   2.18     0  0.458      7.147  54.2  6.0622    3  222
#
#    ptratio       b  lstat  House Price
# 0     15.3  396.90   4.98         24.0
# 1     17.8  396.90   9.14         21.6
# 2     17.8  392.83   4.03         34.7
# 3     18.7  394.63   2.94         33.4
# 4     18.7  396.90   5.33         36.2

# %%
df['chas'] = df['chas'].replace({-1: 0, 2: 1})
print(df['chas'].unique())
# Out:
# [0 1]

# %%
import matplotlib.pyplot as plt
plt.plot(df.index, df['House Price'])
plt.xlabel("Index")
plt.ylabel("House Price")
plt.title("House Price Trend")
plt.show()
df['chas'].value_counts().plot(kind='bar')
plt.xlabel("chas")
plt.ylabel("Count")
plt.title("CHAS Distribution")
plt.show()

# %%
plt.scatter(df['Avg Rooms'], df['House Price'])
plt.xlabel("Average Rooms")
plt.ylabel("House Price")
plt.title("Rooms vs House Price")
plt.show()

# %%
plt.hist(df['House Price'], bins=10)
plt.xlabel("House Price")
plt.ylabel("Frequency")
plt.title("House Price Distribution")
plt.show()

# %%
plt.boxplot(df['House Price'])
plt.xlabel("House Price")
plt.title("House Price Boxplot")
plt.show()
