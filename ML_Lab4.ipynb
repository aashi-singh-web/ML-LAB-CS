# %% [markdown]
# <a href="https://colab.research.google.com/github/aashi-singh-web/ML-LAB-CS/blob/main/ML_Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("/content/Iris.csv")

print(df.head())
print(df.tail())
print(df.tail(2).head(1))
print(df.shape)
print(df.columns)
df.info()
print(df.describe())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 148  149            6.2           3.4            5.4           2.3
#
#             Species
# 148  Iris-virginica
# (150, 6)
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
print(df.tail(n=1))
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 149  Iris-virginica

# %%
print(df.loc[0])
# Out:
# Id                         1
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object

# %%
print(df.loc[20])
# Out:
# Id                        21
# SepalLengthCm            5.4
# SepalWidthCm             3.4
# PetalLengthCm            1.7
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 20, dtype: object

# %%
print(df.loc[[80, 149]])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 80    81            5.5           2.4            3.8           1.1
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 80   Iris-versicolor
# 149   Iris-virginica

# %%
print(df.loc[[0, 99, 149]])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 99   100            5.7           2.8            4.1           1.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 0        Iris-setosa
# 99   Iris-versicolor
# 149   Iris-virginica

# %%
print(df.iloc[1])
# Out:
# Id                         2
# SepalLengthCm            4.9
# SepalWidthCm             3.0
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 1, dtype: object

# %%
print(df.iloc[99])
# Out:
# Id                           100
# SepalLengthCm                5.7
# SepalWidthCm                 2.8
# PetalLengthCm                4.1
# PetalWidthCm                 1.3
# Species          Iris-versicolor
# Name: 99, dtype: object

# %%
print(df.iloc[-1])
# Out:
# Id                          150
# SepalLengthCm               5.9
# SepalWidthCm                3.0
# PetalLengthCm               5.1
# PetalWidthCm                1.8
# Species          Iris-virginica
# Name: 149, dtype: object

# %%
print(df.iloc[[0, 99, 149]])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 99   100            5.7           2.8            4.1           1.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 0        Iris-setosa
# 99   Iris-versicolor
# 149   Iris-virginica

# %%
subset = df.loc[:, ['SepalLengthCm']]

# %%
print(subset.head())
# Out:
#    SepalLengthCm
# 0            5.1
# 1            4.9
# 2            4.7
# 3            4.6
# 4            5.0

# %%
subset = df.loc[:, ['SepalLengthCm','SepalWidthCm']]

# %%
print(subset.head())
# Out:
#    SepalLengthCm  SepalWidthCm
# 0            5.1           3.5
# 1            4.9           3.0
# 2            4.7           3.2
# 3            4.6           3.1
# 4            5.0           3.6

# %%
subset2 = df.iloc[:, [2, 4]]
print(subset2.head())
# Out:
#    SepalWidthCm  PetalWidthCm
# 0           3.5           0.2
# 1           3.0           0.2
# 2           3.2           0.2
# 3           3.1           0.2
# 4           3.6           0.2

# %%
print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
subset3=df.iloc[:,[2,3,-1]]
print(subset3.head())
# Out:
#    SepalWidthCm  PetalLengthCm      Species
# 0           3.5            1.4  Iris-setosa
# 1           3.0            1.4  Iris-setosa
# 2           3.2            1.3  Iris-setosa
# 3           3.1            1.5  Iris-setosa
# 4           3.6            1.4  Iris-setosa

# %%
list1 = list(range(6))
print(list1)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
subset4=df.iloc[:,list1]
print(subset4.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(df.loc[20,'SepalWidthCm'])
# Out:
# 3.4

# %%
print(df.iloc[20,2])
# Out:
# 3.4

# %%
print(df.iloc[[0, 99, 149], [0, 3, 5]])
# Out:
#       Id  PetalLengthCm          Species
# 0      1            1.4      Iris-setosa
# 99   100            4.1  Iris-versicolor
# 149  150            5.1   Iris-virginica

# %%
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
print(df.notnull().sum())
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
df.loc[10:15, 'SepalLengthCm'] = np.nan

# %%
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    6
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.loc[20:25, 'PetalWidthCm'] = np.nan
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    6
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     6
# Species          0
# dtype: int64

# %%
df['SepalLengthCm'].fillna(df['SepalLengthCm'].mean(), inplace=True)
# Out:
# /tmp/ipython-input-1892212042.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['SepalLengthCm'].fillna(df['SepalLengthCm'].mean(), inplace=True)

# %%
df['PetalWidthCm'].fillna(df['PetalWidthCm'].median(), inplace=True)
# Out:
# /tmp/ipython-input-2227252488.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PetalWidthCm'].fillna(df['PetalWidthCm'].median(), inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.rename(columns={'SepalLengthCm': 'SepalLength'}, inplace=True)

# %%
print(df.columns)
# Out:
# Index(['Id', 'SepalLength', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df['SepalLength']=df['SepalLength'].astype(float)

# %%
df['PetalWidthCm']=df['PetalWidthCm'].astype(float)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLength    150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
#  6   SepalLengthCm  150 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 8.3+ KB
# None

# %%
print(df.iloc[-1])
# Out:
# Id                          150
# SepalLength                 5.9
# SepalWidthCm                3.0
# PetalLengthCm               5.1
# PetalWidthCm                1.8
# Species          Iris-virginica
# SepalLengthCm               5.9
# Name: 149, dtype: object

# %%
df['Species'].replace({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}, inplace=True)
# Out:
# /tmp/ipython-input-3346091399.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Species'].replace({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}, inplace=True)
# /tmp/ipython-input-3346091399.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Species'].replace({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}, inplace=True)
